# %% [markdown]
# # Super Category View

# %% [markdown]
# - Consumption Summary

# %% [markdown]
# - ALPHA

# %%
import pandas as pd

# %%
# %run "Advance_Pipeline_Billing_Prashanth_Reports.ipynb"

# %%
# %run "Search Allocation.ipynb"
# Out:
# 289
# 9361205
# 9457362
# 1746457

# %%
# Force pandas to show floats as whole numbers with no decimals
pd.options.display.float_format = '{:,.0f}'.format

# %%
row_data = [
    ('Mobile', 'Mobile'),
    ('Electronics', 'IOT'),
    ('Electronics', 'Storage'),
    ('Electronics', 'MobileAccessory'),
    ('Electronics', 'MobileProtection'),
    ('Electronics', 'ITAccessory'),
    ('Electronics', 'PowerBank'),
    ('Electronics', 'Camera'),
    ('Electronics', 'Audio'),
    ('Electronics', 'Video'),
    ('Electronics', 'LaptopAndDesktop'),
    ('Electronics', 'Tablet'),
    ('Electronics', 'Gaming'),
    ('Electronics', 'ITPeripherals'),
    ('Electronics', 'Automobile'),
    ('Electronics', 'Service'),
    ('Electronics', 'PersonalHealthCare'),
    ('Furniture', 'LargeFurniture'),
    ('Furniture', 'SmallFurniture'),
    ('Home', 'HomeDecor'),
    ('Home', 'HomeFurnishing'),
    ('Home', 'HomeImprovementTool'),
    ('Home', 'HouseHold'),
    ('Large', 'AirConditioner'),
    ('Large', 'CoreEA'),
    ('Large', 'PremiumEA'),
    ('Large', 'SeasonalEA'),
    ('Large', 'HomeEntertainmentLarge'),
    ('Large', 'Microwave'),
    ('Large', 'Refrigerator'),
    ('Large', 'WashingMachineDryer'),
    ('Lifestyle', 'GemsAndJewellery'),
    ('Lifestyle', 'FashionWearables'),
    ('Lifestyle', 'KidClothing'),
    ('Lifestyle', 'KidsFootwear'),
    ('Lifestyle', 'LuggageAndTravelAccessories'),
    ('Lifestyle', 'MensClothingCasualTopwear'),
    ('Lifestyle', 'MensClothingEssentialsAndEthnic'),
    ('Lifestyle', 'MensClothingJeans'),
    ('Lifestyle', 'MensClothingSmartAndFormals'),
    ('Lifestyle', 'MensCnFFootwear'),
    ('Lifestyle', 'MensOpenFootwear'),
    ('Lifestyle', 'MensSportsFootwear'),
    ('Lifestyle', 'Watch'),
    ('Lifestyle', 'WomenEthnicContemporary'),
    ('Lifestyle', 'WomenEthnicCore'),
    ('Lifestyle', 'WomenFW'),
    ('Lifestyle', 'WomenWesternCore'),
    ('Lifestyle', 'WomenWesternGrowth'),
    ('BGM', 'FoodAndNutrition'),
    ('BGM', 'HealthCare'),
    ('BGM', 'HouseHoldSupplies'),
    ('BGM', 'Grooming'),
    ('BGM', 'MakeupFragrances'),
    ('BGM', 'BooksMedia'),
    ('BGM', 'SportFitness'),
    ('BGM', 'ToysAndSS'),
    ('BGM', 'BabyCare'),
    ('BGM', 'AutoAccessorys'),
    ('BGM', 'Industrial&Scientific'),
    ('BGM', 'Pets'),
    ('Grocery', 'Grocery'),
    ('Shopsy', 'ShopsyMobile'),
    ('Shopsy', 'ShopsyBGM'),
    ('Shopsy', 'ShopsyElectronics'),
    ('Shopsy', 'ShopsyFurniture'),
    ('Shopsy', 'ShopsyHome'),
    ('Shopsy', 'ShopsyLarge'),
    ('Shopsy', 'ShopsyLifeStyle'),
    ('Travel', 'Travel'),
    ('Hyperlocal', 'HyperlocalBGM'),
    ('Hyperlocal', 'HyperlocalMobile'),
    ('Hyperlocal', 'HyperlocalElectronics'),
    ('Hyperlocal', 'HyperlocalLifestyle'),
    ('Hyperlocal', 'HyperlocalLarge'),
    ('Hyperlocal', 'HyperlocalHome'),
    ('Hyperlocal', 'HyperlocalGrocery'),
    ('3P', '3P/Non category'),
    ('Not Assigned', 'Not Assigned'),
]

# %%
# Create the Row MultiIndex
row_index = pd.MultiIndex.from_tuples(row_data, names=['BU', 'Super Categories'])

# Create the Column MultiIndex (Main and Sub headers)
main_headers = ['Alpha', 'MP', 'HL']
sub_headers = ['Neo', 'Non-Neo', 'Credits', 'Brand_PLA', 'Brand_PCA']
col_index = pd.MultiIndex.from_product([main_headers, sub_headers], names=['Alpha/MP/HL', 'Type of Ads'])

# Build the final empty DataFrame
df_consumption = pd.DataFrame(0.0, index=row_index, columns=col_index)
df_redemption = pd.DataFrame(0.0, index=row_index, columns=col_index)
df_estimations = pd.DataFrame(0.0, index=row_index, columns=col_index)
df_search_roins = pd.DataFrame(0.0, index=row_index, columns=col_index)

# %%
# Advance Report
def fill_Neo(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[source_df['New Alpha/MP'] == main_col]
    summary = filtered.groupby(['New BU', 'New Supercat'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Neo'
df_consumption = fill_Neo(df_consumption, advance, "Alpha", 'Neo', 'Final Consumption Numbers')

# %%
# Pipiline report
def fill_Non_Neo(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[(source_df['New Alpha/MP'] == main_col) & (source_df['Rate Card Bifurcation'] == "Sponsorship")]
    summary = filtered.groupby(['New BU', 'New Supercat'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Non-Neo'
df_consumption = fill_Non_Neo(df_consumption, pipeline, "Alpha", 'Non-Neo', 'Consumption')

# %%
# BM Raw
def fill_brand_pla(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[(source_df['Alpha/MP'] == main_col) & (source_df['campaign_type'] == "BRAND_PLA")]
    summary = filtered.groupby(['New BU', 'New Supercat'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Brand_PLA'
df_consumption = fill_brand_pla(df_consumption, bm_raw_final, "Alpha", 'Brand_PLA', 'Actual_spend')

# %%
# BSS PCA
def fill_brand_pla(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[(source_df['Alpha/MP'] == main_col) & (source_df['Campaign Type'] == "BRAND_PCA")]
    summary = filtered.groupby(['BU', 'Super category'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Brand_PCA'
df_consumption = fill_brand_pla(df_consumption, bss_pca_final, "Alpha", 'Brand_PCA', 'Spend')

# %%
df_consumption.head(50)
# Out:
# Alpha/MP/HL                                      Alpha                  \
# Type of Ads                                        Neo Non-Neo Credits
# BU          Super Categories
# Mobile      Mobile                          45,040,489 268,428       0
# Electronics IOT                             15,891,556       0       0
#             Storage                                  0       0       0
#             MobileAccessory                          0       0       0
#             MobileProtection                         0       0       0
#             ITAccessory                              0       0       0
#             PowerBank                                0       0       0
#             Camera                             484,924       0       0
#             Audio                           69,715,157       0       0
#             Video                                    0       0       0
#             LaptopAndDesktop                   777,449       0       0
#             Tablet                           1,422,411       0       0
#             Gaming                             333,399       0       0
#             ITPeripherals                      132,429       0       0
#             Automobile                               0       0       0
#             Service                                  0       0       0
#             PersonalHealthCare               5,106,291       0       0
# Furniture   LargeFurniture                           0       0       0
#             SmallFurniture                           0       0       0
# Home        HomeDecor                                0       0       0
#             HomeFurnishing                           0       0       0
#             HomeImprovementTool                  9,248       0       0
#             HouseHold                           55,955       0       0
# Large       AirConditioner                           0       0       0
#             CoreEA                             100,889       0       0
#             PremiumEA                           97,201       0       0
#             SeasonalEA                          72,220       0       0
#             HomeEntertainmentLarge             373,611       0       0
#             Microwave                                0       0       0
#             Refrigerator                     1,232,868       0       0
#             WashingMachineDryer                770,799       0       0
# Lifestyle   GemsAndJewellery                         0       0       0
#             FashionWearables                         0       0       0
#             KidClothing                              0       0       0
#             KidsFootwear                             0       0       0
#             LuggageAndTravelAccessories      1,891,164       0       0
#             MensClothingCasualTopwear                0       0       0
#             MensClothingEssentialsAndEthnic          0       0       0
#             MensClothingJeans                        0       0       0
#             MensClothingSmartAndFormals              0       0       0
#             MensCnFFootwear                          0       0       0
#             MensOpenFootwear                         0       0       0
#             MensSportsFootwear                 628,226       0       0
#             Watch                              627,715       0       0
#             WomenEthnicContemporary                  0       0       0
#             WomenEthnicCore                          0       0       0
#             WomenFW                                  0       0       0
#             WomenWesternCore                         0       0       0
#             WomenWesternGrowth                       0       0       0
# BGM         FoodAndNutrition                 2,505,588       0       0
#
# Alpha/MP/HL                                                        MP          \
# Type of Ads                                  Brand_PLA  Brand_PCA Neo Non-Neo
# BU          Super Categories
# Mobile      Mobile                          44,218,579 17,189,575   0       0
# Electronics IOT                             26,868,769  4,699,931   0       0
#             Storage                            398,951     47,972   0       0
#             MobileAccessory                    116,614    116,278   0       0
#             MobileProtection                    12,773     72,990   0       0
#             ITAccessory                        977,630     76,540   0       0
#             PowerBank                        5,447,546    855,265   0       0
#             Camera                             412,064    229,255   0       0
#             Audio                           54,290,057 10,405,707   0       0
#             Video                                9,162      1,326   0       0
#             LaptopAndDesktop                 3,681,801  1,159,976   0       0
#             Tablet                             754,007    377,585   0       0
#             Gaming                             138,349      3,488   0       0
#             ITPeripherals                    2,532,067    727,385   0       0
#             Automobile                               0          1   0       0
#             Service                                  0          0   0       0
#             PersonalHealthCare               4,170,549    582,664   0       0
# Furniture   LargeFurniture                     792,369    153,500   0       0
#             SmallFurniture                      51,401      1,742   0       0
# Home        HomeDecor                        1,426,582    133,942   0       0
#             HomeFurnishing                     378,526     35,602   0       0
#             HomeImprovementTool                623,069     78,581   0       0
#             HouseHold                        6,668,087    580,531   0       0
# Large       AirConditioner                   3,370,897    230,968   0       0
#             CoreEA                           6,775,535    733,634   0       0
#             PremiumEA                        4,526,801    909,238   0       0
#             SeasonalEA                       7,620,737    565,483   0       0
#             HomeEntertainmentLarge           6,192,839    947,633   0       0
#             Microwave                          583,587     73,514   0       0
#             Refrigerator                     4,552,895    551,531   0       0
#             WashingMachineDryer              7,701,648  1,067,694   0       0
# Lifestyle   GemsAndJewellery                         0          0   0       0
#             FashionWearables                   298,422    185,537   0       0
#             KidClothing                        160,204      7,369   0       0
#             KidsFootwear                       235,719      3,291   0       0
#             LuggageAndTravelAccessories     39,205,049  2,904,553   0       0
#             MensClothingCasualTopwear        2,042,775     41,503   0       0
#             MensClothingEssentialsAndEthnic  4,298,477     30,669   0       0
#             MensClothingJeans                        0     77,128   0       0
#             MensClothingSmartAndFormals              0     84,206   0       0
#             MensCnFFootwear                  5,122,409    774,552   0       0
#             MensOpenFootwear                   269,210          0   0       0
#             MensSportsFootwear              13,432,116  1,322,133   0       0
#             Watch                            6,660,518    318,268   0       0
#             WomenEthnicContemporary            319,662          0   0       0
#             WomenEthnicCore                    158,752    125,077   0       0
#             WomenFW                          1,011,501     87,994   0       0
#             WomenWesternCore                   190,766     97,745   0       0
#             WomenWesternGrowth                 323,080          0   0       0
# BGM         FoodAndNutrition                16,058,333  3,346,331   0       0
#
# Alpha/MP/HL                                                              HL  \
# Type of Ads                                 Credits Brand_PLA Brand_PCA Neo
# BU          Super Categories
# Mobile      Mobile                                0         0         0   0
# Electronics IOT                                   0         0         0   0
#             Storage                               0         0         0   0
#             MobileAccessory                       0         0         0   0
#             MobileProtection                      0         0         0   0
#             ITAccessory                           0         0         0   0
#             PowerBank                             0         0         0   0
#             Camera                                0         0         0   0
#             Audio                                 0         0         0   0
#             Video                                 0         0         0   0
#             LaptopAndDesktop                      0         0         0   0
#             Tablet                                0         0         0   0
#             Gaming                                0         0         0   0
#             ITPeripherals                         0         0         0   0
#             Automobile                            0         0         0   0
#             Service                               0         0         0   0
#             PersonalHealthCare                    0         0         0   0
# Furniture   LargeFurniture                        0         0         0   0
#             SmallFurniture                        0         0         0   0
# Home        HomeDecor                             0         0         0   0
#             HomeFurnishing                        0         0         0   0
#             HomeImprovementTool                   0         0         0   0
#             HouseHold                             0         0         0   0
# Large       AirConditioner                        0         0         0   0
#             CoreEA                                0         0         0   0
#             PremiumEA                             0         0         0   0
#             SeasonalEA                            0         0         0   0
#             HomeEntertainmentLarge                0         0         0   0
#             Microwave                             0         0         0   0
#             Refrigerator                          0         0         0   0
#             WashingMachineDryer                   0         0         0   0
# Lifestyle   GemsAndJewellery                      0         0         0   0
#             FashionWearables                      0         0         0   0
#             KidClothing                           0         0         0   0
#             KidsFootwear                          0         0         0   0
#             LuggageAndTravelAccessories           0         0         0   0
#             MensClothingCasualTopwear             0         0         0   0
#             MensClothingEssentialsAndEthnic       0         0         0   0
#             MensClothingJeans                     0         0         0   0
#             MensClothingSmartAndFormals           0         0         0   0
#             MensCnFFootwear                       0         0         0   0
#             MensOpenFootwear                      0         0         0   0
#             MensSportsFootwear                    0         0         0   0
#             Watch                                 0         0         0   0
#             WomenEthnicContemporary               0         0         0   0
#             WomenEthnicCore                       0         0         0   0
#             WomenFW                               0         0         0   0
#             WomenWesternCore                      0         0         0   0
#             WomenWesternGrowth                    0         0         0   0
# BGM         FoodAndNutrition                      0         0         0   0
#
# Alpha/MP/HL                                                            \
# Type of Ads                                 Non-Neo Credits Brand_PLA
# BU          Super Categories
# Mobile      Mobile                                0       0         0
# Electronics IOT                                   0       0         0
#             Storage                               0       0         0
#             MobileAccessory                       0       0         0
#             MobileProtection                      0       0         0
#             ITAccessory                           0       0         0
#             PowerBank                             0       0         0
#             Camera                                0       0         0
#             Audio                                 0       0         0
#             Video                                 0       0         0
#             LaptopAndDesktop                      0       0         0
#             Tablet                                0       0         0
#             Gaming                                0       0         0
#             ITPeripherals                         0       0         0
#             Automobile                            0       0         0
#             Service                               0       0         0
#             PersonalHealthCare                    0       0         0
# Furniture   LargeFurniture                        0       0         0
#             SmallFurniture                        0       0         0
# Home        HomeDecor                             0       0         0
#             HomeFurnishing                        0       0         0
#             HomeImprovementTool                   0       0         0
#             HouseHold                             0       0         0
# Large       AirConditioner                        0       0         0
#             CoreEA                                0       0         0
#             PremiumEA                             0       0         0
#             SeasonalEA                            0       0         0
#             HomeEntertainmentLarge                0       0         0
#             Microwave                             0       0         0
#             Refrigerator                          0       0         0
#             WashingMachineDryer                   0       0         0
# Lifestyle   GemsAndJewellery                      0       0         0
#             FashionWearables                      0       0         0
#             KidClothing                           0       0         0
#             KidsFootwear                          0       0         0
#             LuggageAndTravelAccessories           0       0         0
#             MensClothingCasualTopwear             0       0         0
#             MensClothingEssentialsAndEthnic       0       0         0
#             MensClothingJeans                     0       0         0
#             MensClothingSmartAndFormals           0       0         0
#             MensCnFFootwear                       0       0         0
#             MensOpenFootwear                      0       0         0
#             MensSportsFootwear                    0       0         0
#             Watch                                 0       0         0
#             WomenEthnicContemporary               0       0         0
#             WomenEthnicCore                       0       0         0
#             WomenFW                               0       0         0
#             WomenWesternCore                      0       0         0
#             WomenWesternGrowth                    0       0         0
# BGM         FoodAndNutrition                      0       0         0
#
# Alpha/MP/HL
# Type of Ads                                 Brand_PCA
# BU          Super Categories
# Mobile      Mobile                                  0
# Electronics IOT                                     0
#             Storage                                 0
#             MobileAccessory                         0
#             MobileProtection                        0
#             ITAccessory                             0
#             PowerBank                               0
#             Camera                                  0
#             Audio                                   0
#             Video                                   0
#             LaptopAndDesktop                        0
#             Tablet                                  0
#             Gaming                                  0
#             ITPeripherals                           0
#             Automobile                              0
#             Service                                 0
#             PersonalHealthCare                      0
# Furniture   LargeFurniture                          0
#             SmallFurniture                          0
# Home        HomeDecor                               0
#             HomeFurnishing                          0
#             HomeImprovementTool                     0
#             HouseHold                               0
# Large       AirConditioner                          0
#             CoreEA                                  0
#             PremiumEA                               0
#             SeasonalEA                              0
#             HomeEntertainmentLarge                  0
#             Microwave                               0
#             Refrigerator                            0
#             WashingMachineDryer                     0
# Lifestyle   GemsAndJewellery                        0
#             FashionWearables                        0
#             KidClothing                             0
#             KidsFootwear                            0
#             LuggageAndTravelAccessories             0
#             MensClothingCasualTopwear               0
#             MensClothingEssentialsAndEthnic         0
#             MensClothingJeans                       0
#             MensClothingSmartAndFormals             0
#             MensCnFFootwear                         0
#             MensOpenFootwear                        0
#             MensSportsFootwear                      0
#             Watch                                   0
#             WomenEthnicContemporary                 0
#             WomenEthnicCore                         0
#             WomenFW                                 0
#             WomenWesternCore                        0
#             WomenWesternGrowth                      0
# BGM         FoodAndNutrition                        0
