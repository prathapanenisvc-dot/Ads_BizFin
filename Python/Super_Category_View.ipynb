# %% [markdown]
# # Super Category View

# %% [markdown]
# - Consumption Summary

# %% [markdown]
# - ALPHA

# %%
import pandas as pd

# %%
# %run "Advance_Pipeline_Billing_Prashanth_Reports.ipynb"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2192 entries, 0 to 2191
# Data columns (total 62 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Row #                                   2188 non-null   object
#  1   Ext RO Number Flag                      2188 non-null   object
#  2   External RO number                      1032 non-null   object
#  3   Billing as per the Internal RO Number?  2188 non-null   object
#  4   Internal RO number                      2188 non-null   object
#  5   RO Business Type                        2188 non-null   object
#  6   Line Item Business Type                 2187 non-null   object
#  7   Advertiser                              2187 non-null   object
#  8   Sales Manager                           2187 non-null   object
#  9   Line Item Name                          2187 non-null   object
#  10  Line Item Id                            2187 non-null   float64
#  11  Industry                                2176 non-null   object
#  12  Inventory Slot Wise                     2187 non-null   object
#  13  Start Date                              2187 non-null   datetime64[ns]
#  14  End Date                                2187 non-null   datetime64[ns]
#  15  Cost Type                               2187 non-null   object
#  16  Original Rate                           2187 non-null   float64
#  17  Negotiated Rate                         2187 non-null   float64
#  18  LineItem Gross Budget                   2187 non-null   float64
#  19  LineItem Net Budget                     2187 non-null   float64
#  20  LineItem Discount                       2187 non-null   float64
#  21  RO Link                                 2187 non-null   object
#  22  RO Supporting Document - External       0 non-null      float64
#  23  Internal Additional Document            1099 non-null   object
#  24  Folder Link                             0 non-null      float64
#  25  Campaign Id                             1435 non-null   object
#  26  Remaining Budget                        2187 non-null   float64
#  27  Actual Revenue                          882 non-null    float64
#  28  Gross Actual Revenue                    882 non-null    float64
#  29  Net Actual Revenue                      882 non-null    float64
#  30  Final Billing Revenue                   882 non-null    float64
#  31  Billed Revenue                          2187 non-null   float64
#  32  Over/Under Delivery                     2187 non-null   float64
#  33  POE                                     0 non-null      float64
#  34  POE Type                                0 non-null      float64
#  35  POC Name                                0 non-null      float64
#  36  Agency/Direct                           0 non-null      float64
#  37  1P/3P                                   2133 non-null   object
#  38  Industry.1                              2187 non-null   object
#  39  RO Brand                                2187 non-null   object
#  40  RO Brand Text                           555 non-null    object
#  41  RO Brand Grouping                       555 non-null    object
#  42  Mall Eligibility                        1830 non-null   object
#  43  RO Amount                               2187 non-null   float64
#  44  RO Start Date                           2187 non-null   datetime64[ns]
#  45  RO End Date                             2187 non-null   datetime64[ns]
#  46  RO Period                               2187 non-null   float64
#  47  RO Amount Without Tax                   2187 non-null   float64
#  48  Tax                                     2187 non-null   float64
#  49  RO Amount With Tax                      2187 non-null   float64
#  50  Amount to be billed by FKN to brand     2187 non-null   float64
#  51  GST                                     2180 non-null   object
#  52  CEF Number                              111 non-null    object
#  53  Pan Card Number                         2161 non-null   object
#  54  Signed RO                               0 non-null      float64
#  55  CEF                                     0 non-null      float64
#  56  Pan Card Copy                           0 non-null      float64
#  57  Payment Terms                           0 non-null      float64
#  58  Folder Link.1                           0 non-null      float64
#  59  Invoice Status                          0 non-null      float64
#  60  Supporting Doc Link                     2171 non-null   object
#  61  LI External Supporting Doc Link         23 non-null     object
# dtypes: datetime64[ns](4), float64(31), object(27)
# memory usage: 1.0+ MB
# C:\Users\prathapanenis.vc\AppData\Local\Temp\ipykernel_25376\245450307.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   advance['Private Brand'] = advance['LookupKey'].map(tagging_map).fillna(0)
# 289
# 9361205
# 9457362
# 1746457

# %%
# %run "Search Allocation.ipynb"
# Out:
# 289
# 9361205
# 9457362
# 1746457

# %%
# Force pandas to show floats as whole numbers with no decimals
pd.options.display.float_format = '{:,.0f}'.format

# %%
row_data = [
    ('Mobile', 'Mobile'),
    ('Electronics', 'IOT'),
    ('Electronics', 'Storage'),
    ('Electronics', 'MobileAccessory'),
    ('Electronics', 'MobileProtection'),
    ('Electronics', 'ITAccessory'),
    ('Electronics', 'PowerBank'),
    ('Electronics', 'Camera'),
    ('Electronics', 'Audio'),
    ('Electronics', 'Video'),
    ('Electronics', 'LaptopAndDesktop'),
    ('Electronics', 'Tablet'),
    ('Electronics', 'Gaming'),
    ('Electronics', 'ITPeripherals'),
    ('Electronics', 'Automobile'),
    ('Electronics', 'Service'),
    ('Electronics', 'PersonalHealthCare'),
    ('Furniture', 'LargeFurniture'),
    ('Furniture', 'SmallFurniture'),
    ('Home', 'HomeDecor'),
    ('Home', 'HomeFurnishing'),
    ('Home', 'HomeImprovementTool'),
    ('Home', 'HouseHold'),
    ('Large', 'AirConditioner'),
    ('Large', 'CoreEA'),
    ('Large', 'PremiumEA'),
    ('Large', 'SeasonalEA'),
    ('Large', 'HomeEntertainmentLarge'),
    ('Large', 'Microwave'),
    ('Large', 'Refrigerator'),
    ('Large', 'WashingMachineDryer'),
    ('Lifestyle', 'GemsAndJewellery'),
    ('Lifestyle', 'FashionWearables'),
    ('Lifestyle', 'KidClothing'),
    ('Lifestyle', 'KidsFootwear'),
    ('Lifestyle', 'LuggageAndTravelAccessories'),
    ('Lifestyle', 'MensClothingCasualTopwear'),
    ('Lifestyle', 'MensClothingEssentialsAndEthnic'),
    ('Lifestyle', 'MensClothingJeans'),
    ('Lifestyle', 'MensClothingSmartAndFormals'),
    ('Lifestyle', 'MensCnFFootwear'),
    ('Lifestyle', 'MensOpenFootwear'),
    ('Lifestyle', 'MensSportsFootwear'),
    ('Lifestyle', 'Watch'),
    ('Lifestyle', 'WomenEthnicContemporary'),
    ('Lifestyle', 'WomenEthnicCore'),
    ('Lifestyle', 'WomenFW'),
    ('Lifestyle', 'WomenWesternCore'),
    ('Lifestyle', 'WomenWesternGrowth'),
    ('BGM', 'FoodAndNutrition'),
    ('BGM', 'HealthCare'),
    ('BGM', 'HouseHoldSupplies'),
    ('BGM', 'Grooming'),
    ('BGM', 'MakeupFragrances'),
    ('BGM', 'BooksMedia'),
    ('BGM', 'SportFitness'),
    ('BGM', 'ToysAndSS'),
    ('BGM', 'BabyCare'),
    ('BGM', 'AutoAccessorys'),
    ('BGM', 'Industrial&Scientific'),
    ('BGM', 'Pets'),
    ('Grocery', 'Grocery'),
    ('Shopsy', 'ShopsyMobile'),
    ('Shopsy', 'ShopsyBGM'),
    ('Shopsy', 'ShopsyElectronics'),
    ('Shopsy', 'ShopsyFurniture'),
    ('Shopsy', 'ShopsyHome'),
    ('Shopsy', 'ShopsyLarge'),
    ('Shopsy', 'ShopsyLifeStyle'),
    ('Travel', 'Travel'),
    ('Hyperlocal', 'HyperlocalBGM'),
    ('Hyperlocal', 'HyperlocalMobile'),
    ('Hyperlocal', 'HyperlocalElectronics'),
    ('Hyperlocal', 'HyperlocalLifestyle'),
    ('Hyperlocal', 'HyperlocalLarge'),
    ('Hyperlocal', 'HyperlocalHome'),
    ('Hyperlocal', 'HyperlocalGrocery'),
    ('3P', '3P/Non category'),
    ('Not Assigned', 'Not Assigned'),
]

# %%
# Create the Row MultiIndex
row_index = pd.MultiIndex.from_tuples(row_data, names=['BU', 'Super Categories'])

# Create the Column MultiIndex (Main and Sub headers)
main_headers = ['Alpha', 'MP', 'HL']
sub_headers = ['Neo', 'Non-Neo', 'Credits', 'Brand_PLA', 'Brand_PCA']
col_index = pd.MultiIndex.from_product([main_headers, sub_headers], names=['Alpha/MP/HL', 'Type of Ads'])

# Build the final empty DataFrame
df_consumption = pd.DataFrame(0.0, index=row_index, columns=col_index)
df_redemption = pd.DataFrame(0.0, index=row_index, columns=col_index)
df_estimations = pd.DataFrame(0.0, index=row_index, columns=col_index)
df_search_roins = pd.DataFrame(0.0, index=row_index, columns=col_index)

# %%
# Advance Report
def fill_Neo(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[source_df['New Alpha/MP'] == main_col]
    summary = filtered.groupby(['New BU', 'New Supercat'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Neo'
df_consumption = fill_Neo(df_consumption, advance, "Alpha", 'Neo', 'Final Consumption Numbers')

# %%
# Pipiline report
def fill_Non_Neo(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[(source_df['New Alpha/MP'] == main_col) & (source_df['Rate Card Bifurcation'] == "Sponsorship")]
    summary = filtered.groupby(['New BU', 'New Supercat'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Non-Neo'
df_consumption = fill_Non_Neo(df_consumption, pipeline, "Alpha", 'Non-Neo', 'Consumption')

# %%
# BM Raw
def fill_brand_pla(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[(source_df['Alpha/MP'] == main_col) & (source_df['campaign_type'] == "BRAND_PLA")]
    summary = filtered.groupby(['New BU', 'New Supercat'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Brand_PLA'
df_consumption = fill_brand_pla(df_consumption, bm_raw_final, "Alpha", 'Brand_PLA', 'Actual_spend')

# %%
# BSS PCA
def fill_brand_pla(template_df, source_df, main_col, sub_col, sum_col):
    filtered = source_df[(source_df['Alpha/MP'] == main_col) & (source_df['Campaign Type'] == "BRAND_PCA")]
    summary = filtered.groupby(['BU', 'Super category'])[sum_col].sum()
    template_df.loc[:, (main_col, sub_col)] = summary.reindex(template_df.index).fillna(0)
    
    return template_df

# %%
# 'Brand_PCA'
df_consumption = fill_brand_pla(df_consumption, bss_pca_final, "Alpha", 'Brand_PCA', 'Spend')

# %%
# df_consumption.head(50)
